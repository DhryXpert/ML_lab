# %%
import tensorflow as tf
from tensorflow.keras import datasets

(x_train, y_train), (x_test, y_test) = datasets.boston_housing.load_data()

print('Training set: ', x_train.shape, y_train.shape)
print('Test set: ', x_test.shape, y_test.shape)
# Out:
# Training set:  (404, 13) (404,)
# Test set:  (102, 13) (102,)

# %%
y_train[:5]
# Out:
# array([15.2, 42.3, 50. , 21.1, 17.7])

# %%
x_train[0]
# Out:
# array([  1.23247,   0.     ,   8.14   ,   0.     ,   0.538  ,   6.142  ,
#         91.7    ,   3.9769 ,   4.     , 307.     ,  21.     , 396.9    ,
#         18.72   ])

# %%
# Build ANN Arch for Regression
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.utils import plot_model

model_reg = Sequential([
    Input((13,)),
    Dense(1, activation='linear')
])

# Model Training
model_reg.compile(optimizer='sgd', loss='msle', metrics=['accuracy', 'msle'])
model_reg.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 3.9616 - msle: 3.9616
# Epoch 2/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 4.0068 - msle: 4.0068
# Epoch 3/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 4.9491 - msle: 4.9491
# Epoch 4/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 5.2330 - msle: 5.2330
# Epoch 5/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 9.4462 - msle: 9.4462
# Epoch 6/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0000e+00 - loss: 4.3897 - msle: 4.3897
# Epoch 7/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 3.7491 - msle: 3.7491
# Epoch 8/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 7.1083 - msle: 7.1083
# Epoch 9/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 5.4550 - msle: 5.4550
# Epoch 10/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 6.1539 - msle: 6.1539

# %%
# Evaluate the model
model_reg.evaluate(x_test, y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0000e+00 - loss: 9.8067 - msle: 9.8067
# [9.806747436523438, 0.0, 9.806747436523438]

# %%
# Build ANN Arch for Regression
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.utils import plot_model

model_reg_1 = Sequential()
model_reg_1.add(Dense(50, activation='relu', input_shape=(x_train.shape[1], )))
model_reg_1.add(Dense(25, activation='relu'))
model_reg_1.add(Dense(12, activation='relu'))
model_reg_1.add(Dense(1, activation='linear'))

# Model Training
model_reg_1.compile(optimizer='adam', loss='msle', metrics=['accuracy', 'msle'])
model_reg_1.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test), batch_size=32)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.0000e+00 - loss: 1.1008 - msle: 1.1008 - val_accuracy: 0.0000e+00 - val_loss: 0.2398 - val_msle: 0.2398
# Epoch 2/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.2240 - msle: 0.2240 - val_accuracy: 0.0000e+00 - val_loss: 0.2365 - val_msle: 0.2365
# Epoch 3/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.1520 - msle: 0.1520 - val_accuracy: 0.0000e+00 - val_loss: 0.1497 - val_msle: 0.1497
# Epoch 4/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.1120 - msle: 0.1120 - val_accuracy: 0.0000e+00 - val_loss: 0.1300 - val_msle: 0.1300
# Epoch 5/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.1023 - msle: 0.1023 - val_accuracy: 0.0000e+00 - val_loss: 0.1318 - val_msle: 0.1318
# Epoch 6/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.1011 - msle: 0.1011 - val_accuracy: 0.0000e+00 - val_loss: 0.1684 - val_msle: 0.1684
# Epoch 7/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0984 - msle: 0.0984 - val_accuracy: 0.0000e+00 - val_loss: 0.1235 - val_msle: 0.1235
# Epoch 8/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0928 - msle: 0.0928 - val_accuracy: 0.0000e+00 - val_loss: 0.1224 - val_msle: 0.1224
# Epoch 9/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0965 - msle: 0.0965 - val_accuracy: 0.0000e+00 - val_loss: 0.1241 - val_msle: 0.1241
# Epoch 10/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0925 - msle: 0.0925 - val_accuracy: 0.0000e+00 - val_loss: 0.1215 - val_msle: 0.1215

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

bank_ds = pd.read_csv('/content/Bank(1).csv', delimiter=';')

le = LabelEncoder()

for col in ['job', 'marital', 'default', 'education', 'housing', 'loan', 'contact', 'month']:
    bank_ds[col] = le.fit_transform(bank_ds[col])
bank_ds.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4939/3514107769.py in <cell line: 0>()
#       2 from sklearn.preprocessing import LabelEncoder
#       3
# ----> 4 bank_ds = pd.read_csv('/content/Bank(1).csv', delimiter=';')
#       5
#       6 le = LabelEncoder()
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Bank(1).csv'

# %%
x = bank_ds.iloc[:,:-1].values
y = bank_ds.iloc[:,-1].values

from sklearn.preprocessing import StandardScaler

x_std = StandardScaler().fit_transform(x)

x_std[0]

# %%
# ANN
model_bc = Sequential()
model_bc.add(Dense(20, activation='relu', input_shape=(16,)))
model_bc.add(Dense(5, activation='relu'))
model_bc.add(Dense(1, activation='sigmoid'))  # binary classification uses sigmoid as activation

model_bc.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_bc.fit(x, y, epochs=10, batch_size=128, validation_split=0.2)

# %%
# prediction of new
pred_proba = model_bc.predict(x)

pred = []

for proba in pred_proba:
    if proba >= 0.5:
        pred.append(1)
    else:
        pred.append(0)

# %%
from sklearn.metrics import classification_report

cls = classification_report(y, pred)
print(cls)

# %%
from tensorflow.keras import losses
from tensorflow.keras import optimizers
from sklearn import datasets
from tensorflow.keras.utils import to_categorical

iris_ds = datasets.load_iris()

x = iris_ds.data
y = iris_ds.target

y_cat = to_categorical(y, num_classes=3)  # one-hot encoding

# %%
model_mc = Sequential()
model_mc.add(Dense(10, activation='relu', input_shape=(4,)))
model_mc.add(Dense(5, activation='relu'))
model_mc.add(Dense(3, activation='softmax'))  # multiclass classification uses softmax

model_mc.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model_mc.fit(x, y_cat, epochs=4, batch_size=64, validation_split=0.2)

# %%
import numpy as np

x.shape
np.unique(y)

# %%
y_pred_proba = model_mc.predict(x)

y_pred = []
for proba in y_pred_proba:
    y_pred.append(np.argmax(proba))

print(classification_report(y, y_pred))
